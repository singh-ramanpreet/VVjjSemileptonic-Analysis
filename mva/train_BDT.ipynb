# %%
import ROOT
import json
import os
# Out:
# Welcome to JupyROOT 6.18/00

# %%
class args:
    out_dir = "BDT_1"
    datasets = "../datasets_2016.json"

# %%
dataloader_name = args.out_dir
os.makedirs(dataloader_name, exist_ok=True)
output_file = ROOT.TFile(f"{dataloader_name}/training_output.root", "recreate")
factory = ROOT.TMVA.Factory(
    "VBS",
    output_file,
    ":".join([
        "!V", "!Silent",
        "Color", "DrawProgressBar",
        "Transformations=I",
        f"AnalysisType=Classification"
    ])
)
dataloader = ROOT.TMVA.DataLoader(dataloader_name)

# %%
samples_dict = json.load(open(args.datasets, "r"))
input_trees = []
for key in samples_dict:
    location = samples_dict[key]["location"]
    filelist = samples_dict[key]["filelist"]
    lumi = samples_dict[key]["lumi"]

    for sample in filelist:
        root_file = location + sample["name"]
        xs = sample["xs"]
        nMC = sample["nMC"]
        nMCneg = sample["nMCneg"]

        xs_weight = (lumi * xs) / (nMC - (2 * nMCneg))

        root_file = ROOT.TFile.Open(root_file)

        if key == "VBS_EWK":
            input_trees.append((root_file, xs_weight, "Signal"))

        elif key == "WJets":
            input_trees.append((root_file, xs_weight, "Background"))

        else:
            continue

for i_tree, treeWeight, treeClass in input_trees:
    dataloader.AddTree(i_tree.Get("otree"), treeClass, treeWeight)
# Out:
# DataSetInfo              : [BDT_1] : Added class "Signal"
#                          : Add Tree otree of type Signal with 26095 events
#                          : Add Tree otree of type Signal with 23888 events
#                          : Add Tree otree of type Signal with 16938 events
#                          : Add Tree otree of type Signal with 104489 events
#                          : Add Tree otree of type Signal with 28705 events
#                          : Add Tree otree of type Signal with 101123 events
#                          : Add Tree otree of type Signal with 28317 events
#                          : Add Tree otree of type Signal with 32276 events
#                          : Add Tree otree of type Signal with 20595 events
# DataSetInfo              : [BDT_1] : Added class "Background"
#                          : Add Tree otree of type Background with 93 events
#                          : Add Tree otree of type Background with 7226 events
#                          : Add Tree otree of type Background with 54532 events
#                          : Add Tree otree of type Background with 519001 events
#                          : Add Tree otree of type Background with 475646 events
#                          : Add Tree otree of type Background with 659290 events
#                          : Add Tree otree of type Background with 272335 events

# %%
variables = [
    "njets",
    "l_pt1", 
    "l_eta1",
    "pfMET_Corr",
    "vbf_maxpt_jj_m", 
    "vbf_maxpt_jj_Deta",
    "vbf_maxpt_j1_pt",
    "vbf_maxpt_j1_eta",
    "vbf_maxpt_j2_pt",
    "vbf_maxpt_j2_eta",
    # AK8 jet
    "PuppiAK8_jet_mass_so_corr",
    "ungroomed_PuppiAK8_jet_pt",
    "ungroomed_PuppiAK8_jet_eta",
    # WV
    "mass_lvj_type0_PuppiAK8",
    "pt_lvj_type0_PuppiAK8",
    "eta_lvj_type0_PuppiAK8",
    "BosonCentrality_type0",
    "ZeppenfeldWH_dEtajj := ZeppenfeldWH/vbf_maxpt_jj_Deta",
    "ZeppenfeldWL_dEtajj := ZeppenfeldWL_type0/vbf_maxpt_jj_Deta",
    # angles
    "costheta1_type0",
    "costheta2_type0",
    "phi_type0",
    "phi1_type0",
    "costhetastar_type0",
    # W
    "v_pt_type0",
    "v_eta_type0",
    "v_mt_type0",
    "ht := ungroomed_PuppiAK8_jet_pt+vbf_maxpt_j1_pt+vbf_maxpt_j2_pt"
]

for var in variables:
    dataloader.AddVariable(var, "F")

# gen weights
dataloader.SetSignalWeightExpression("genWeight")
dataloader.SetBackgroundWeightExpression("genWeight")

# %%
preselection = """
(type==1 || type==0) 
&& (l_pt2<0)
&& (l_pt1>30)
&& (pfMET_Corr>50)
&& (nBTagJet_loose==0)
&& (vbf_maxpt_j1_pt>30)
&& (vbf_maxpt_j2_pt>30) 
&& (vbf_maxpt_jj_m>500)
&& (vbf_maxpt_jj_Deta>2.5)
&& (ungroomed_PuppiAK8_jet_pt>200)
&& (abs(ungroomed_PuppiAK8_jet_eta)<2.4)
&& (PuppiAK8_jet_mass_so_corr>65)
&& (PuppiAK8_jet_mass_so_corr<105)
&& (BosonCentrality_type0>0.0)
&& (abs(ZeppenfeldWL_type0/vbf_maxpt_jj_Deta)<1.0)
&& (abs(ZeppenfeldWH/vbf_maxpt_jj_Deta)<1.0)
"""
preselection = preselection.replace("\n", " ")

# %%
nTrain = 0
nTest = 0
dataloader.PrepareTrainingAndTestTree(
    ROOT.TCut(preselection),
    ":".join([
        "!V",
        "SplitMode=Random",
        "NormMode=NumEvents",
        f"nTrain_Signal={nTrain}",
        f"nTest_Signal={nTest}",
        f"nTrain_Background={nTrain}",
        f"nTest_Background={nTest}"
    ])
)
# Out:
#                          : Dataset[BDT_1] : Class index : 0  name : Signal
#                          : Dataset[BDT_1] : Class index : 1  name : Background

# %%
factory.BookMethod(
    dataloader,
    ROOT.TMVA.Types.kBDT,
    "BDTG",
    ":".join([
        "!H", "!V",
        "NTrees=500",
        "MinNodeSize=2.5%",
        "BoostType=Grad",
        "Shrinkage=0.10",
        "UseBaggedBoost", "BaggedSampleFraction=0.5",
        "NegWeightTreatment=Pray"
    ])
)
# Out:
# <ROOT.TMVA::MethodBDT object ("BDTG") at 0x76a2910>
# Factory                  : Booking method: BDTG
#                          :
# <WARNING>                : Found events with NaN and/or +-inf values
# <WARNING>                : Dataset[BDT_1] : Input expression resolves to indeterminate value (NaN): phi_type0 (36 times)
# <WARNING>                : These NaN and/or +-infs were all removed by the specified cut, continuing.
#                          :
# DataSetFactory           : [BDT_1] : Number of events in input trees
#                          : Dataset[BDT_1] :     Signal     requirement: " (type==1 || type==0)  && (l_pt2<0) && (l_pt1>30) && (pfMET_Corr>50) && (nBTagJet_loose==0) && (vbf_maxpt_j1_pt>30) && (vbf_maxpt_j2_pt>30)  && (vbf_maxpt_jj_m>500) && (vbf_maxpt_jj_Deta>2.5) && (ungroomed_PuppiAK8_jet_pt>200) && (abs(ungroomed_PuppiAK8_jet_eta)<2.4) && (PuppiAK8_jet_mass_so_corr>65) && (PuppiAK8_jet_mass_so_corr<105) && (BosonCentrality_type0>0.0) && (abs(ZeppenfeldWL_type0/vbf_maxpt_jj_Deta)<1.0) && (abs(ZeppenfeldWH/vbf_maxpt_jj_Deta)<1.0) "
#                          : Dataset[BDT_1] :     Signal          -- number of events passed: 7719   / sum of weights: 111.918
#                          : Dataset[BDT_1] :     Signal          -- efficiency             : 0.0209004
#                          : Dataset[BDT_1] :     Background requirement: " (type==1 || type==0)  && (l_pt2<0) && (l_pt1>30) && (pfMET_Corr>50) && (nBTagJet_loose==0) && (vbf_maxpt_j1_pt>30) && (vbf_maxpt_j2_pt>30)  && (vbf_maxpt_jj_m>500) && (vbf_maxpt_jj_Deta>2.5) && (ungroomed_PuppiAK8_jet_pt>200) && (abs(ungroomed_PuppiAK8_jet_eta)<2.4) && (PuppiAK8_jet_mass_so_corr>65) && (PuppiAK8_jet_mass_so_corr<105) && (BosonCentrality_type0>0.0) && (abs(ZeppenfeldWL_type0/vbf_maxpt_jj_Deta)<1.0) && (abs(ZeppenfeldWH/vbf_maxpt_jj_Deta)<1.0) "
#                          : Dataset[BDT_1] :     Background      -- number of events passed: 79842  / sum of weights: 3661.69
#                          : Dataset[BDT_1] :     Background      -- efficiency             : 0.0702927
#                          : Dataset[BDT_1] :  you have opted for interpreting the requested number of training/testing events
#                          :  to be the number of events AFTER your preselection cuts
#                          :
#                          : Dataset[BDT_1] :  you have opted for interpreting the requested number of training/testing events
#                          :  to be the number of events AFTER your preselection cuts
#                          :
#                          : Number of training and testing events
#                          : ---------------------------------------------------------------------------
#                          : Signal     -- training events            : 3859
#                          : Signal     -- testing events             : 3859
#                          : Signal     -- training and testing events: 7718
#                          : Dataset[BDT_1] : Signal     -- due to the preselection a scaling factor has been applied to the numbers of requested events: 0.0201843
#                          : Background -- training events            : 39921
#                          : Background -- testing events             : 39921
#                          : Background -- training and testing events: 79842
#                          : Dataset[BDT_1] : Background -- due to the preselection a scaling factor has been applied to the numbers of requested events: 0.0401595
#                          :
# DataSetInfo              : Correlation matrix (Signal):
#                          : ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#                          :                                                              njets   l_pt1  l_eta1 pfMET_Corr vbf_maxpt_jj_m vbf_maxpt_jj_Deta vbf_maxpt_j1_pt vbf_maxpt_j1_eta vbf_maxpt_j2_pt vbf_maxpt_j2_eta PuppiAK8_jet_mass_so_corr ungroomed_PuppiAK8_jet_pt ungroomed_PuppiAK8_jet_eta mass_lvj_type0_PuppiAK8 pt_lvj_type0_PuppiAK8 eta_lvj_type0_PuppiAK8 BosonCentrality_type0 ZeppenfeldWH/vbf_maxpt_jj_Deta ZeppenfeldWL_type0/vbf_maxpt_jj_Deta costheta1_type0 costheta2_type0 phi_type0 phi1_type0 costhetastar_type0 v_pt_type0 v_eta_type0 v_mt_type0 ungroomed_PuppiAK8_jet_pt+vbf_maxpt_j1_pt+vbf_maxpt_j2_pt
#                          :                                                     njets:  +1.000  -0.013  -0.010     -0.032         -0.238            -0.409          +0.219           +0.021          +0.150           -0.020                    -0.002                    +0.101                     -0.000                  -0.072                +0.268                 -0.011                -0.277                         +0.002                               -0.001          +0.014          +0.050    -0.020     -0.023             +0.003     -0.038      -0.010     +0.043                                                    +0.214
#                          :                                                     l_pt1:  -0.013  +1.000  -0.027     +0.066         +0.032            +0.024          +0.036           +0.022          +0.012           -0.018                    +0.031                    +0.282                     +0.014                  +0.538                +0.023                 -0.013                +0.033                         +0.018                               -0.025          +0.482          +0.041    +0.026     -0.006             -0.026     +0.669      -0.028     +0.145                                                    +0.169
#                          :                                                    l_eta1:  -0.010  -0.027  +1.000     +0.028         +0.029            +0.025          -0.005           +0.085          +0.012           +0.081                    +0.010                    -0.007                     +0.059                  +0.016                -0.011                 +0.505                +0.012                         -0.166                               +0.666          -0.016          -0.009    -0.015     -0.016             +0.507     +0.007      +0.944     -0.020                                                    -0.004
#                          :                                                pfMET_Corr:  -0.032  +0.066  +0.028     +1.000         +0.032            +0.052          +0.034           -0.012          -0.006           +0.016                    +0.078                    +0.340                     +0.022                  +0.534                +0.037                 +0.043                +0.115                         +0.012                               +0.021          -0.520          +0.044    +0.014     +0.032             +0.004     +0.764      +0.028     -0.190                                                    +0.193
#                          :                                            vbf_maxpt_jj_m:  -0.238  +0.032  +0.029     +0.032         +1.000            +0.508          +0.255           -0.019          +0.355           +0.020                    -0.032                    +0.056                     +0.001                  +0.040                +0.168                 +0.013                +0.360                         -0.003                               +0.015          +0.042          -0.032    +0.019     +0.013             +0.015     +0.036      +0.024     +0.033                                                    +0.261
#                          :                                         vbf_maxpt_jj_Deta:  -0.409  +0.024  +0.025     +0.052         +0.508            +1.000          -0.472           +0.011          -0.419           +0.006                    -0.022                    -0.121                     -0.003                  +0.139                -0.355                 +0.013                +0.637                         -0.023                               -0.004          -0.033          -0.077    +0.034     +0.008             +0.009     +0.058      +0.023     -0.043                                                    -0.435
#                          :                                           vbf_maxpt_j1_pt:  +0.219  +0.036  -0.005     +0.034         +0.255            -0.472          +1.000           -0.014          +0.430           +0.001                    -0.010                    +0.348                     +0.006                  -0.061                +0.778                 -0.005                -0.300                         +0.021                               +0.014          +0.070          +0.066    -0.014     +0.014             -0.005     +0.032      -0.008     +0.068                                                    +0.857
#                          :                                          vbf_maxpt_j1_eta:  +0.021  +0.022  +0.085     -0.012         -0.019            +0.011          -0.014           +1.000          -0.024           -0.851                    -0.014                    -0.001                     -0.065                  +0.018                -0.008                 -0.010                -0.002                         -0.031                               +0.101          +0.016          -0.003    +0.017     +0.007             +0.097     +0.001      +0.077     +0.040                                                    -0.015
#                          :                                           vbf_maxpt_j2_pt:  +0.150  +0.012  +0.012     -0.006         +0.355            -0.419          +0.430           -0.024          +1.000           +0.014                    -0.015                    +0.089                     +0.012                  -0.061                +0.267                 +0.009                -0.229                         +0.019                               +0.025          +0.041          +0.025    -0.014     -0.002             +0.008     -0.002      +0.012     +0.041                                                    +0.534
#                          :                                          vbf_maxpt_j2_eta:  -0.020  -0.018  +0.081     +0.016         +0.020            +0.006          +0.001           -0.851          +0.014           +1.000                    +0.011                    +0.001                     +0.223                  -0.009                -0.002                 +0.196                -0.002                         -0.192                               -0.304          -0.011          +0.000    -0.010     -0.014             -0.128     +0.006      +0.097     -0.042                                                    +0.005
#                          :                                 PuppiAK8_jet_mass_so_corr:  -0.002  +0.031  +0.010     +0.078         -0.032            -0.022          -0.010           -0.014          -0.015           +0.011                    +1.000                    +0.145                     -0.011                  +0.136                +0.024                 -0.015                -0.029                         -0.008                               +0.002          -0.056          -0.049    +0.010     -0.017             +0.006     +0.084      +0.001     -0.054                                                    +0.065
#                          :                                 ungroomed_PuppiAK8_jet_pt:  +0.101  +0.282  -0.007     +0.340         +0.056            -0.121          +0.348           -0.001          +0.089           +0.001                    +0.145                    +1.000                     +0.002                  +0.549                +0.448                 -0.006                -0.036                         -0.002                               -0.009          -0.014          +0.162    +0.010     +0.001             -0.007     +0.417      -0.006     -0.010                                                    +0.736
#                          :                                ungroomed_PuppiAK8_jet_eta:  -0.000  +0.014  +0.059     +0.022         +0.001            -0.003          +0.006           -0.065          +0.012           +0.223                    -0.011                    +0.002                     +1.000                  -0.026                +0.011                 +0.753                +0.021                         +0.698                               -0.177          +0.009          +0.001    +0.006     +0.004             -0.761     +0.021      +0.069     +0.008                                                    +0.007
#                          :                                   mass_lvj_type0_PuppiAK8:  -0.072  +0.538  +0.016     +0.534         +0.040            +0.139          -0.061           +0.018          -0.061           -0.009                    +0.136                    +0.549                     -0.026                  +1.000                -0.064                 -0.006                -0.059                         -0.026                               +0.004          -0.037          +0.090    +0.028     +0.000             +0.020     +0.722      +0.017     -0.025                                                    +0.233
#                          :                                     pt_lvj_type0_PuppiAK8:  +0.268  +0.023  -0.011     +0.037         +0.168            -0.355          +0.778           -0.008          +0.267           -0.002                    +0.024                    +0.448                     +0.011                  -0.064                +1.000                 -0.012                -0.236                         +0.022                               +0.004          +0.105          +0.079    -0.023     +0.011             -0.022     +0.021      -0.015     +0.079                                                    +0.742
#                          :                                    eta_lvj_type0_PuppiAK8:  -0.011  -0.013  +0.505     +0.043         +0.013            +0.013          -0.005           -0.010          +0.009           +0.196                    -0.015                    -0.006                     +0.753                  -0.006                -0.012                 +1.000                +0.023                         +0.428                               +0.207          -0.007          +0.015    -0.007     -0.009             -0.262     +0.022      +0.520     -0.010                                                    -0.004
#                          :                                     BosonCentrality_type0:  -0.277  +0.033  +0.012     +0.115         +0.360            +0.637          -0.300           -0.002          -0.229           -0.002                    -0.029                    -0.036                     +0.021                  -0.059                -0.236                 +0.023                +1.000                         +0.020                               +0.018          -0.072          -0.050    +0.038     +0.032             -0.002     +0.113      +0.013     -0.061                                                    -0.246
#                          :                            ZeppenfeldWH/vbf_maxpt_jj_Deta:  +0.002  +0.018  -0.166     +0.012         -0.003            -0.023          +0.021           -0.031          +0.019           -0.192                    -0.008                    -0.002                     +0.698                  -0.026                +0.022                 +0.428                +0.020                         +1.000                               +0.127          +0.005          +0.002    +0.002     +0.015             -0.664     +0.017      -0.166     +0.015                                                    +0.015
#                          :                      ZeppenfeldWL_type0/vbf_maxpt_jj_Deta:  -0.001  -0.025  +0.666     +0.021         +0.015            -0.004          +0.014           +0.101          +0.025           -0.304                    +0.002                    -0.009                     -0.177                  +0.004                +0.004                 +0.207                +0.018                         +0.127                               +1.000          -0.028          -0.001    -0.025     -0.003             +0.555     +0.003      +0.708     -0.007                                                    +0.010
#                          :                                           costheta1_type0:  +0.014  +0.482  -0.016     -0.520         +0.042            -0.033          +0.070           +0.016          +0.041           -0.011                    -0.056                    -0.014                     +0.009                  -0.037                +0.105                 -0.007                -0.072                         +0.005                               -0.028          +1.000          -0.014    -0.001     -0.016             -0.023     -0.108      -0.025     +0.308                                                    +0.043
#                          :                                           costheta2_type0:  +0.050  +0.041  -0.009     +0.044         -0.032            -0.077          +0.066           -0.003          +0.025           +0.000                    -0.049                    +0.162                     +0.001                  +0.090                +0.079                 +0.015                -0.050                         +0.002                               -0.001          -0.014          +1.000    +0.031     -0.039             +0.003     +0.059      -0.004     -0.001                                                    +0.127
#                          :                                                 phi_type0:  -0.020  +0.026  -0.015     +0.014         +0.019            +0.034          -0.014           +0.017          -0.014           -0.010                    +0.010                    +0.010                     +0.006                  +0.028                -0.023                 -0.007                +0.038                         +0.002                               -0.025          -0.001          +0.031    +1.000     +0.024             -0.016     +0.023      -0.022     +0.025                                                    -0.006
#                          :                                                phi1_type0:  -0.023  -0.006  -0.016     +0.032         +0.013            +0.008          +0.014           +0.007          -0.002           -0.014                    -0.017                    +0.001                     +0.004                  +0.000                +0.011                 -0.009                +0.032                         +0.015                               -0.003          -0.016          -0.039    +0.024     +1.000             -0.007     +0.015      -0.015     +0.008                                                    +0.008
#                          :                                        costhetastar_type0:  +0.003  -0.026  +0.507     +0.004         +0.015            +0.009          -0.005           +0.097          +0.008           -0.128                    +0.006                    -0.007                     -0.761                  +0.020                -0.022                 -0.262                -0.002                         -0.664                               +0.555          -0.023          +0.003    -0.016     -0.007             +1.000     -0.009      +0.512     -0.018                                                    -0.004
#                          :                                                v_pt_type0:  -0.038  +0.669  +0.007     +0.764         +0.036            +0.058          +0.032           +0.001          -0.002           +0.006                    +0.084                    +0.417                     +0.021                  +0.722                +0.021                 +0.022                +0.113                         +0.017                               +0.003          -0.108          +0.059    +0.023     +0.015             -0.009     +1.000      +0.008     -0.197                                                    +0.233
#                          :                                               v_eta_type0:  -0.010  -0.028  +0.944     +0.028         +0.024            +0.023          -0.008           +0.077          +0.012           +0.097                    +0.001                    -0.006                     +0.069                  +0.017                -0.015                 +0.520                +0.013                         -0.166                               +0.708          -0.025          -0.004    -0.022     -0.015             +0.512     +0.008      +1.000     -0.022                                                    -0.005
#                          :                                                v_mt_type0:  +0.043  +0.145  -0.020     -0.190         +0.033            -0.043          +0.068           +0.040          +0.041           -0.042                    -0.054                    -0.010                     +0.008                  -0.025                +0.079                 -0.010                -0.061                         +0.015                               -0.007          +0.308          -0.001    +0.025     +0.008             -0.018     -0.197      -0.022     +1.000                                                    +0.044
#                          : ungroomed_PuppiAK8_jet_pt+vbf_maxpt_j1_pt+vbf_maxpt_j2_pt:  +0.214  +0.169  -0.004     +0.193         +0.261            -0.435          +0.857           -0.015          +0.534           +0.005                    +0.065                    +0.736                     +0.007                  +0.233                +0.742                 -0.004                -0.246                         +0.015                               +0.010          +0.043          +0.127    -0.006     +0.008             -0.004     +0.233      -0.005     +0.044                                                    +1.000
#                          : ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# DataSetInfo              : Correlation matrix (Background):
#                          : ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#                          :                                                              njets   l_pt1  l_eta1 pfMET_Corr vbf_maxpt_jj_m vbf_maxpt_jj_Deta vbf_maxpt_j1_pt vbf_maxpt_j1_eta vbf_maxpt_j2_pt vbf_maxpt_j2_eta PuppiAK8_jet_mass_so_corr ungroomed_PuppiAK8_jet_pt ungroomed_PuppiAK8_jet_eta mass_lvj_type0_PuppiAK8 pt_lvj_type0_PuppiAK8 eta_lvj_type0_PuppiAK8 BosonCentrality_type0 ZeppenfeldWH/vbf_maxpt_jj_Deta ZeppenfeldWL_type0/vbf_maxpt_jj_Deta costheta1_type0 costheta2_type0 phi_type0 phi1_type0 costhetastar_type0 v_pt_type0 v_eta_type0 v_mt_type0 ungroomed_PuppiAK8_jet_pt+vbf_maxpt_j1_pt+vbf_maxpt_j2_pt
#                          :                                                     njets:  +1.000  -0.006  -0.002     -0.014         -0.070            -0.230          +0.136           +0.008          +0.161           -0.000                    +0.027                    +0.041                     -0.000                  -0.035                +0.201                 +0.002                -0.127                         -0.005                               -0.008          +0.023          -0.009    -0.000     +0.001             -0.004     -0.021      -0.002     +0.032                                                    +0.140
#                          :                                                     l_pt1:  -0.006  +1.000  +0.003     +0.021         -0.013            +0.025          -0.005           -0.006          -0.003           +0.018                    +0.032                    +0.208                     +0.011                  +0.479                -0.003                 +0.009                +0.017                         -0.010                               -0.016          +0.495          +0.046    -0.001     -0.006             -0.003     +0.624      -0.001     +0.186                                                    +0.101
#                          :                                                    l_eta1:  -0.002  +0.003  +1.000     -0.010         +0.001            -0.002          +0.001           +0.211          +0.001           -0.092                    -0.004                    +0.011                     +0.192                  -0.014                -0.003                 +0.636                +0.004                         +0.041                               +0.730          +0.016          +0.013    +0.001     +0.004             +0.534     -0.006      +0.949     -0.003                                                    +0.006
#                          :                                                pfMET_Corr:  -0.014  +0.021  -0.010     +1.000         -0.005            -0.002          +0.032           +0.003          +0.018           +0.009                    +0.036                    +0.263                     -0.013                  +0.493                +0.030                 -0.014                +0.060                         -0.022                               -0.018          -0.533          +0.034    -0.004     -0.015             +0.002     +0.764      -0.010     -0.116                                                    +0.156
#                          :                                            vbf_maxpt_jj_m:  -0.070  -0.013  +0.001     -0.005         +1.000            +0.490          +0.244           -0.000          +0.276           +0.001                    +0.021                    +0.073                     +0.000                  +0.043                +0.187                 -0.000                +0.222                         -0.004                               +0.001          +0.041          -0.003    -0.009     +0.013             -0.003     -0.018      +0.003     +0.018                                                    +0.247
#                          :                                         vbf_maxpt_jj_Deta:  -0.230  +0.025  -0.002     -0.002         +0.490            +1.000          -0.501           +0.006          -0.449           -0.008                    -0.017                    -0.112                     +0.006                  +0.088                -0.293                 +0.002                +0.554                         +0.005                               +0.004          -0.005          -0.023    +0.005     +0.017             -0.009     +0.023      -0.002     -0.024                                                    -0.464
#                          :                                           vbf_maxpt_j1_pt:  +0.136  -0.005  +0.001     +0.032         +0.244            -0.501          +1.000           -0.006          +0.328           +0.010                    +0.051                    +0.352                     -0.007                  -0.046                +0.718                 -0.004                -0.328                         -0.010                               -0.004          +0.063          +0.048    -0.007     -0.001             +0.005     +0.001      +0.004     +0.062                                                    +0.867
#                          :                                          vbf_maxpt_j1_eta:  +0.008  -0.006  +0.211     +0.003         -0.000            +0.006          -0.006           +1.000          -0.012           -0.808                    +0.007                    +0.009                     +0.048                  -0.006                -0.003                 +0.149                +0.001                         +0.080                               +0.209          -0.003          -0.001    -0.008     +0.012             +0.103     -0.002      +0.199     -0.004                                                    -0.002
#                          :                                           vbf_maxpt_j2_pt:  +0.161  -0.003  +0.001     +0.018         +0.276            -0.449          +0.328           -0.012          +1.000           +0.013                    +0.010                    +0.045                     -0.002                  -0.012                +0.166                 +0.003                -0.237                         -0.006                               -0.005          +0.013          -0.005    -0.008     -0.009             +0.004     +0.008      +0.002     +0.009                                                    +0.444
#                          :                                          vbf_maxpt_j2_eta:  -0.000  +0.018  -0.092     +0.009         +0.001            -0.008          +0.010           -0.808          +0.013           +1.000                    -0.002                    -0.002                     +0.148                  +0.012                +0.012                 +0.034                +0.001                         -0.364                               -0.455          +0.010          +0.009    +0.004     -0.005             -0.172     +0.019      -0.059     +0.005                                                    +0.008
#                          :                                 PuppiAK8_jet_mass_so_corr:  +0.027  +0.032  -0.004     +0.036         +0.021            -0.017          +0.051           +0.007          +0.010           -0.002                    +1.000                    +0.158                     -0.008                  +0.094                +0.064                 -0.014                -0.014                         -0.010                               -0.004          -0.010          -0.066    -0.016     +0.000             +0.003     +0.048      -0.007     -0.002                                                    +0.114
#                          :                                 ungroomed_PuppiAK8_jet_pt:  +0.041  +0.208  +0.011     +0.263         +0.073            -0.112          +0.352           +0.009          +0.045           -0.002                    +0.158                    +1.000                     -0.008                  +0.505                +0.444                 +0.004                -0.054                         -0.010                               +0.003          -0.031          +0.172    -0.005     -0.008             +0.013     +0.320      +0.009     +0.011                                                    +0.731
#                          :                                ungroomed_PuppiAK8_jet_eta:  -0.000  +0.011  +0.192     -0.013         +0.000            +0.006          -0.007           +0.048          -0.002           +0.148                    -0.008                    -0.008                     +1.000                  +0.004                +0.004                 +0.727                -0.002                         +0.623                               -0.056          +0.006          +0.008    +0.009     -0.005             -0.647     -0.004      +0.203     -0.001                                                    -0.008
#                          :                                   mass_lvj_type0_PuppiAK8:  -0.035  +0.479  -0.014     +0.493         +0.043            +0.088          -0.046           -0.006          -0.012           +0.012                    +0.094                    +0.505                     +0.004                  +1.000                -0.057                 -0.009                -0.102                         -0.004                               -0.021          -0.044          +0.071    +0.002     -0.019             -0.009     +0.662      -0.020     +0.029                                                    +0.223
#                          :                                     pt_lvj_type0_PuppiAK8:  +0.201  -0.003  -0.003     +0.030         +0.187            -0.293          +0.718           -0.003          +0.166           +0.012                    +0.064                    +0.444                     +0.004                  -0.057                +1.000                 -0.004                -0.184                         -0.006                               -0.013          +0.108          +0.058    -0.004     +0.004             -0.009     -0.012      -0.004     +0.102                                                    +0.703
#                          :                                    eta_lvj_type0_PuppiAK8:  +0.002  +0.009  +0.636     -0.014         -0.000            +0.002          -0.004           +0.149          +0.003           +0.034                    -0.014                    +0.004                     +0.727                  -0.009                -0.004                 +1.000                +0.003                         +0.409                               +0.367          +0.021          +0.003    +0.009     +0.001             -0.065     -0.005      +0.656     -0.002                                                    +0.000
#                          :                                     BosonCentrality_type0:  -0.127  +0.017  +0.004     +0.060         +0.222            +0.554          -0.328           +0.001          -0.237           +0.001                    -0.014                    -0.054                     -0.002                  -0.102                -0.184                 +0.003                +1.000                         -0.008                               +0.002          -0.061          -0.004    -0.002     +0.025             +0.007     +0.067      +0.005     -0.050                                                    -0.282
#                          :                            ZeppenfeldWH/vbf_maxpt_jj_Deta:  -0.005  -0.010  +0.041     -0.022         -0.004            +0.005          -0.010           +0.080          -0.006           -0.364                    -0.010                    -0.010                     +0.623                  -0.004                -0.006                 +0.409                -0.008                         +1.000                               +0.330          -0.009          +0.002    +0.009     -0.011             -0.474     -0.023      +0.018     -0.004                                                    -0.013
#                          :                      ZeppenfeldWL_type0/vbf_maxpt_jj_Deta:  -0.008  -0.016  +0.730     -0.018         +0.001            +0.004          -0.004           +0.209          -0.005           -0.455                    -0.004                    +0.003                     -0.056                  -0.021                -0.013                 +0.367                +0.002                         +0.330                               +1.000          +0.005          +0.002    +0.004     -0.000             +0.587     -0.025      +0.745     -0.003                                                    -0.001
#                          :                                           costheta1_type0:  +0.023  +0.495  +0.016     -0.533         +0.041            -0.005          +0.063           -0.003          +0.013           +0.010                    -0.010                    -0.031                     +0.006                  -0.044                +0.108                 +0.021                -0.061                         -0.009                               +0.005          +1.000          +0.003    -0.002     +0.008             +0.012     -0.129      +0.014     +0.255                                                    +0.026
#                          :                                           costheta2_type0:  -0.009  +0.046  +0.013     +0.034         -0.003            -0.023          +0.048           -0.001          -0.005           +0.009                    -0.066                    +0.172                     +0.008                  +0.071                +0.058                 +0.003                -0.004                         +0.002                               +0.002          +0.003          +1.000    -0.002     +0.003             -0.004     +0.055      +0.010     -0.001                                                    +0.115
#                          :                                                 phi_type0:  -0.000  -0.001  +0.001     -0.004         -0.009            +0.005          -0.007           -0.008          -0.008           +0.004                    -0.016                    -0.005                     +0.009                  +0.002                -0.004                 +0.009                -0.002                         +0.009                               +0.004          -0.002          -0.002    +1.000     -0.007             -0.004     -0.004      +0.001     +0.005                                                    -0.008
#                          :                                                phi1_type0:  +0.001  -0.006  +0.004     -0.015         +0.013            +0.017          -0.001           +0.012          -0.009           -0.005                    +0.000                    -0.008                     -0.005                  -0.019                +0.004                 +0.001                +0.025                         -0.011                               -0.000          +0.008          +0.003    -0.007     +1.000             +0.009     -0.015      +0.006     +0.003                                                    -0.007
#                          :                                        costhetastar_type0:  -0.004  -0.003  +0.534     +0.002         -0.003            -0.009          +0.005           +0.103          +0.004           -0.172                    +0.003                    +0.013                     -0.647                  -0.009                -0.009                 -0.065                +0.007                         -0.474                               +0.587          +0.012          -0.004    -0.004     +0.009             +1.000     +0.001      +0.544     -0.006                                                    +0.011
#                          :                                                v_pt_type0:  -0.021  +0.624  -0.006     +0.764         -0.018            +0.023          +0.001           -0.002          +0.008           +0.019                    +0.048                    +0.320                     -0.004                  +0.662                -0.012                 -0.005                +0.067                         -0.023                               -0.025          -0.129          +0.055    -0.004     -0.015             +0.001     +1.000      -0.009     -0.159                                                    +0.163
#                          :                                               v_eta_type0:  -0.002  -0.001  +0.949     -0.010         +0.003            -0.002          +0.004           +0.199          +0.002           -0.059                    -0.007                    +0.009                     +0.203                  -0.020                -0.004                 +0.656                +0.005                         +0.018                               +0.745          +0.014          +0.010    +0.001     +0.006             +0.544     -0.009      +1.000     -0.004                                                    +0.007
#                          :                                                v_mt_type0:  +0.032  +0.186  -0.003     -0.116         +0.018            -0.024          +0.062           -0.004          +0.009           +0.005                    -0.002                    +0.011                     -0.001                  +0.029                +0.102                 -0.002                -0.050                         -0.004                               -0.003          +0.255          -0.001    +0.005     +0.003             -0.006     -0.159      -0.004     +1.000                                                    +0.046
#                          : ungroomed_PuppiAK8_jet_pt+vbf_maxpt_j1_pt+vbf_maxpt_j2_pt:  +0.140  +0.101  +0.006     +0.156         +0.247            -0.464          +0.867           -0.002          +0.444           +0.008                    +0.114                    +0.731                     -0.008                  +0.223                +0.703                 +0.000                -0.282                         -0.013                               -0.001          +0.026          +0.115    -0.008     -0.007             +0.011     +0.163      +0.007     +0.046                                                    +1.000
#                          : ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# DataSetFactory           : [BDT_1] :
#                          :

# %%
factory.TrainAllMethods()
factory.TestAllMethods()
factory.EvaluateAllMethods()
   
output_file.cd()
output_file.Close()
# Out:
# Factory                  : Train all methods
# Factory                  : [BDT_1] : Create Transformation "I" with events from all classes.
#                          :
#                          : Transformation, Variable selection :
#                          : Input : variable 'njets' <---> Output : variable 'njets'
#                          : Input : variable 'l_pt1' <---> Output : variable 'l_pt1'
#                          : Input : variable 'l_eta1' <---> Output : variable 'l_eta1'
#                          : Input : variable 'pfMET_Corr' <---> Output : variable 'pfMET_Corr'
#                          : Input : variable 'vbf_maxpt_jj_m' <---> Output : variable 'vbf_maxpt_jj_m'
#                          : Input : variable 'vbf_maxpt_jj_Deta' <---> Output : variable 'vbf_maxpt_jj_Deta'
#                          : Input : variable 'vbf_maxpt_j1_pt' <---> Output : variable 'vbf_maxpt_j1_pt'
#                          : Input : variable 'vbf_maxpt_j1_eta' <---> Output : variable 'vbf_maxpt_j1_eta'
#                          : Input : variable 'vbf_maxpt_j2_pt' <---> Output : variable 'vbf_maxpt_j2_pt'
#                          : Input : variable 'vbf_maxpt_j2_eta' <---> Output : variable 'vbf_maxpt_j2_eta'
#                          : Input : variable 'PuppiAK8_jet_mass_so_corr' <---> Output : variable 'PuppiAK8_jet_mass_so_corr'
#                          : Input : variable 'ungroomed_PuppiAK8_jet_pt' <---> Output : variable 'ungroomed_PuppiAK8_jet_pt'
#                          : Input : variable 'ungroomed_PuppiAK8_jet_eta' <---> Output : variable 'ungroomed_PuppiAK8_jet_eta'
#                          : Input : variable 'mass_lvj_type0_PuppiAK8' <---> Output : variable 'mass_lvj_type0_PuppiAK8'
#                          : Input : variable 'pt_lvj_type0_PuppiAK8' <---> Output : variable 'pt_lvj_type0_PuppiAK8'
#                          : Input : variable 'eta_lvj_type0_PuppiAK8' <---> Output : variable 'eta_lvj_type0_PuppiAK8'
#                          : Input : variable 'BosonCentrality_type0' <---> Output : variable 'BosonCentrality_type0'
#                          : Input : variable 'ZeppenfeldWH_dEtajj' <---> Output : variable 'ZeppenfeldWH_dEtajj'
#                          : Input : variable 'ZeppenfeldWL_dEtajj' <---> Output : variable 'ZeppenfeldWL_dEtajj'
#                          : Input : variable 'costheta1_type0' <---> Output : variable 'costheta1_type0'
#                          : Input : variable 'costheta2_type0' <---> Output : variable 'costheta2_type0'
#                          : Input : variable 'phi_type0' <---> Output : variable 'phi_type0'
#                          : Input : variable 'phi1_type0' <---> Output : variable 'phi1_type0'
#                          : Input : variable 'costhetastar_type0' <---> Output : variable 'costhetastar_type0'
#                          : Input : variable 'v_pt_type0' <---> Output : variable 'v_pt_type0'
#                          : Input : variable 'v_eta_type0' <---> Output : variable 'v_eta_type0'
#                          : Input : variable 'v_mt_type0' <---> Output : variable 'v_mt_type0'
#                          : Input : variable 'ht' <---> Output : variable 'ht'
# TFHandler_Factory        :                   Variable                          Mean                          RMS                  [        Min                          Max ]
#                          : -----------------------------------------------------------------------------------------------------------------------------------------------------
#                          :                      njets:                      2.6242                      1.4646   [                      0.0000                      14.000 ]
#                          :                      l_pt1:                      104.62                      83.316   [                      30.001                      1902.7 ]
#                          :                     l_eta1:                   0.0067399                      1.2034   [                     -2.4995                      2.4992 ]
#                          :                 pfMET_Corr:                      135.59                      94.703   [                      50.002                      2249.6 ]
#                          :             vbf_maxpt_jj_m:                      1067.1                      587.87   [                      500.03                      8043.8 ]
#                          :          vbf_maxpt_jj_Deta:                      4.5863                      1.1555   [                      2.5001                      9.3438 ]
#                          :            vbf_maxpt_j1_pt:                      197.34                      138.34   [                      30.050                      3022.6 ]
#                          :           vbf_maxpt_j1_eta:                   0.0078221                      2.1567   [                     -4.8144                      4.8203 ]
#                          :            vbf_maxpt_j2_pt:                      69.171                      50.454   [                      30.000                      1283.9 ]
#                          :           vbf_maxpt_j2_eta:                  -0.0037764                      2.8078   [                     -4.9018                      4.8972 ]
#                          :  PuppiAK8_jet_mass_so_corr:                      81.717                      10.791   [                      65.001                      105.00 ]
#                          :  ungroomed_PuppiAK8_jet_pt:                      320.92                      114.07   [                      200.06                      2864.7 ]
#                          : ungroomed_PuppiAK8_jet_eta:                    0.015348                     0.93527   [                     -2.3974                      2.3982 ]
#                          :    mass_lvj_type0_PuppiAK8:                      629.54                      290.91   [                      157.48                      5254.2 ]
#                          :      pt_lvj_type0_PuppiAK8:                      231.71                      143.69   [                     0.56859                      2696.0 ]
#                          :     eta_lvj_type0_PuppiAK8:                    0.014265                      1.7073   [                     -8.3033                      6.0686 ]
#                          :      BosonCentrality_type0:                     0.98695                     0.67634   [                  8.5831e-06                      4.0514 ]
#                          :        ZeppenfeldWH_dEtajj:                   0.0027800                     0.22846   [                    -0.49986                     0.50000 ]
#                          :        ZeppenfeldWL_dEtajj:                 -2.4011e-05                     0.27677   [                    -0.49997                     0.49997 ]
#                          :            costheta1_type0:                   -0.048253                     0.43336   [                    -0.96175                     0.99967 ]
#                          :            costheta2_type0:                     0.32577                     0.26773   [                    -0.94046                      1.0000 ]
#                          :                  phi_type0:                   0.0066285                      1.7950   [                     -3.1405                      3.1410 ]
#                          :                 phi1_type0:                  -0.0013514                      1.7915   [                     -3.1415                      3.1415 ]
#                          :         costhetastar_type0:                  -0.0070260                     0.54020   [                    -0.99993                     0.99999 ]
#                          :                 v_pt_type0:                      220.02                      136.36   [                      4.4971                      2386.9 ]
#                          :                v_eta_type0:                   0.0031443                      1.1069   [                     -3.5391                      4.0138 ]
#                          :                 v_mt_type0:                      68.336                      48.927   [                   0.0023840                      912.92 ]
#                          :                         ht:                      587.43                      227.08   [                      269.75                      5491.5 ]
#                          : -----------------------------------------------------------------------------------------------------------------------------------------------------
#                          :
#                          : <PlotVariables> Will not produce scatter plots ==>
#                          : |  The number of 28 input variables and 0 target values would require 378 two-dimensional
#                          : |  histograms, which would occupy the computer's memory. Note that this
#                          : |  suppression does not have any consequences for your analysis, other
#                          : |  than not disposing of these scatter plots. You can modify the maximum
#                          : |  number of input variables allowed to generate scatter plots in your
#                          : |  script via the command line:
#                          : |  "(TMVA::gConfig().GetVariablePlotting()).fMaxNumOfAllowedVariablesForScatterPlots = <some int>;"
#                          :
#                          : Some more output
#                          : Ranking input variables (method unspecific)...
# IdTransformation         : Ranking result (top variable is best ranked)
#                          : ---------------------------------------------------
#                          : Rank : Variable                   : Separation
#                          : ---------------------------------------------------
#                          :    1 : vbf_maxpt_jj_m             : 1.429e-01
#                          :    2 : vbf_maxpt_j2_pt            : 7.155e-02
#                          :    3 : ht                         : 5.085e-02
#                          :    4 : ZeppenfeldWL_dEtajj        : 4.921e-02
#                          :    5 : njets                      : 4.109e-02
#                          :    6 : BosonCentrality_type0      : 3.652e-02
#                          :    7 : PuppiAK8_jet_mass_so_corr  : 3.337e-02
#                          :    8 : vbf_maxpt_j1_pt            : 2.910e-02
#                          :    9 : l_eta1                     : 2.266e-02
#                          :   10 : ungroomed_PuppiAK8_jet_pt  : 2.046e-02
#                          :   11 : mass_lvj_type0_PuppiAK8    : 1.734e-02
#                          :   12 : vbf_maxpt_j1_eta           : 1.678e-02
#                          :   13 : v_pt_type0                 : 1.458e-02
#                          :   14 : pt_lvj_type0_PuppiAK8      : 1.395e-02
#                          :   15 : l_pt1                      : 1.347e-02
#                          :   16 : vbf_maxpt_jj_Deta          : 1.291e-02
#                          :   17 : v_eta_type0                : 1.137e-02
#                          :   18 : costhetastar_type0         : 9.144e-03
#                          :   19 : ungroomed_PuppiAK8_jet_eta : 6.992e-03
#                          :   20 : vbf_maxpt_j2_eta           : 6.276e-03
#                          :   21 : v_mt_type0                 : 6.131e-03
#                          :   22 : costheta1_type0            : 5.997e-03
#                          :   23 : pfMET_Corr                 : 5.811e-03
#                          :   24 : phi1_type0                 : 5.716e-03
#                          :   25 : eta_lvj_type0_PuppiAK8     : 4.792e-03
#                          :   26 : ZeppenfeldWH_dEtajj        : 4.583e-03
#                          :   27 : costheta2_type0            : 3.771e-03
#                          :   28 : phi_type0                  : 2.698e-03
#                          : ---------------------------------------------------
# Factory                  : Train method: BDTG for Classification
#                          :
# BDTG                     : #events: (reweighted) sig: 21890 bkg: 21890
#                          : #events: (unweighted) sig: 3859 bkg: 39921
#                          : Training 500 Decision Trees ... patience please
#                          : Elapsed time for training with 43780 events: 33.8 sec
# BDTG                     : [BDT_1] : Evaluation of BDTG on training sample (43780 events)
#                          : Elapsed time for evaluation of 43780 events: 3.08 sec
#                          : Creating xml weight file: BDT_1/weights/VBS_BDTG.weights.xml
#                          : Creating standalone class: BDT_1/weights/VBS_BDTG.class.C
#                          : BDT_1/training_output.root:/BDT_1/Method_BDT/BDTG
# Factory                  : Training finished
#                          :
#                          : Ranking input variables (method specific)...
# BDTG                     : Ranking result (top variable is best ranked)
#                          : ------------------------------------------------------------
#                          : Rank : Variable                   : Variable Importance
#                          : ------------------------------------------------------------
#                          :    1 : PuppiAK8_jet_mass_so_corr  : 5.320e-02
#                          :    2 : phi1_type0                 : 4.616e-02
#                          :    3 : ZeppenfeldWL_dEtajj        : 4.593e-02
#                          :    4 : phi_type0                  : 4.588e-02
#                          :    5 : vbf_maxpt_jj_m             : 4.361e-02
#                          :    6 : costheta2_type0            : 4.342e-02
#                          :    7 : l_eta1                     : 4.067e-02
#                          :    8 : ZeppenfeldWH_dEtajj        : 4.050e-02
#                          :    9 : vbf_maxpt_j2_eta           : 4.031e-02
#                          :   10 : costheta1_type0            : 4.015e-02
#                          :   11 : costhetastar_type0         : 3.977e-02
#                          :   12 : BosonCentrality_type0      : 3.771e-02
#                          :   13 : vbf_maxpt_j1_eta           : 3.682e-02
#                          :   14 : ungroomed_PuppiAK8_jet_eta : 3.672e-02
#                          :   15 : vbf_maxpt_jj_Deta          : 3.655e-02
#                          :   16 : v_eta_type0                : 3.431e-02
#                          :   17 : njets                      : 3.330e-02
#                          :   18 : eta_lvj_type0_PuppiAK8     : 3.227e-02
#                          :   19 : v_mt_type0                 : 3.146e-02
#                          :   20 : mass_lvj_type0_PuppiAK8    : 3.061e-02
#                          :   21 : v_pt_type0                 : 3.004e-02
#                          :   22 : vbf_maxpt_j2_pt            : 2.960e-02
#                          :   23 : pt_lvj_type0_PuppiAK8      : 2.843e-02
#                          :   24 : vbf_maxpt_j1_pt            : 2.804e-02
#                          :   25 : ht                         : 2.400e-02
#                          :   26 : l_pt1                      : 2.359e-02
#                          :   27 : ungroomed_PuppiAK8_jet_pt  : 2.350e-02
#                          :   28 : pfMET_Corr                 : 2.345e-02
#                          : ------------------------------------------------------------
# Factory                  : === Destroy and recreate all methods via weight files for testing ===
#                          :
#                          : Reading weight file: BDT_1/weights/VBS_BDTG.weights.xml
# Factory                  : Test all methods
# Factory                  : Test method: BDTG for Classification performance
#                          :
# BDTG                     : [BDT_1] : Evaluation of BDTG on testing sample (43780 events)
#                          : Elapsed time for evaluation of 43780 events: 1.62 sec
# Factory                  : Evaluate all methods
# Factory                  : Evaluate classifier: BDTG
#                          :
# BDTG                     : [BDT_1] : Loop over test events and fill histograms with classifier response...
#                          :
# TFHandler_BDTG           :                   Variable                          Mean                          RMS                  [        Min                          Max ]
#                          : -----------------------------------------------------------------------------------------------------------------------------------------------------
#                          :                      njets:                      2.6524                      1.4750   [                      0.0000                      13.000 ]
#                          :                      l_pt1:                      102.99                      83.223   [                      30.002                      1774.1 ]
#                          :                     l_eta1:                    0.023385                      1.2226   [                     -2.4961                      2.4978 ]
#                          :                 pfMET_Corr:                      134.26                      92.499   [                      50.001                      2493.3 ]
#                          :             vbf_maxpt_jj_m:                      1038.5                      560.66   [                      500.02                      7058.9 ]
#                          :          vbf_maxpt_jj_Deta:                      4.5659                      1.1543   [                      2.5001                      9.2917 ]
#                          :            vbf_maxpt_j1_pt:                      196.11                      136.66   [                      30.322                      2707.7 ]
#                          :           vbf_maxpt_j1_eta:                    0.020543                      2.1443   [                     -4.8469                      4.8705 ]
#                          :            vbf_maxpt_j2_pt:                      67.350                      48.733   [                      30.000                      1354.8 ]
#                          :           vbf_maxpt_j2_eta:                  -0.0029358                      2.8106   [                     -4.8757                      4.8711 ]
#                          :  PuppiAK8_jet_mass_so_corr:                      81.666                      10.933   [                      65.001                      105.00 ]
#                          :  ungroomed_PuppiAK8_jet_pt:                      318.76                      111.88   [                      200.01                      3175.8 ]
#                          : ungroomed_PuppiAK8_jet_eta:                    0.012969                     0.93070   [                     -2.3998                      2.3983 ]
#                          :    mass_lvj_type0_PuppiAK8:                      624.70                      286.51   [                      162.84                      4849.4 ]
#                          :      pt_lvj_type0_PuppiAK8:                      231.02                      142.87   [                      3.0711                      2808.3 ]
#                          :     eta_lvj_type0_PuppiAK8:                    0.029273                      1.7218   [                     -7.3490                      7.0784 ]
#                          :      BosonCentrality_type0:                     0.96708                     0.67211   [                  1.7934e-05                      4.3809 ]
#                          :        ZeppenfeldWH_dEtajj:                  0.00091128                     0.23019   [                    -0.49991                     0.49997 ]
#                          :        ZeppenfeldWL_dEtajj:                   0.0016054                     0.28100   [                    -0.49999                     0.49988 ]
#                          :            costheta1_type0:                   -0.050294                     0.43235   [                    -0.98096                     0.99978 ]
#                          :            costheta2_type0:                     0.32868                     0.26923   [                    -0.95741                     0.99950 ]
#                          :                  phi_type0:                   -0.011651                      1.7905   [                     -3.1413                      3.1402 ]
#                          :                 phi1_type0:                   -0.030533                      1.7933   [                     -3.1413                      3.1415 ]
#                          :         costhetastar_type0:                 -0.00046741                     0.54389   [                    -0.99996                     0.99993 ]
#                          :                 v_pt_type0:                      216.61                      135.01   [                      4.4623                      2575.9 ]
#                          :                v_eta_type0:                    0.014635                      1.1287   [                     -3.2444                      3.6625 ]
#                          :                 v_mt_type0:                      68.363                      48.838   [                   0.0039272                      1285.2 ]
#                          :                         ht:                      582.22                      221.97   [                      267.47                      5923.4 ]
#                          : -----------------------------------------------------------------------------------------------------------------------------------------------------
#                          :
#                          : <PlotVariables> Will not produce scatter plots ==>
#                          : |  The number of 28 input variables and 0 target values would require 378 two-dimensional
#                          : |  histograms, which would occupy the computer's memory. Note that this
#                          : |  suppression does not have any consequences for your analysis, other
#                          : |  than not disposing of these scatter plots. You can modify the maximum
#                          : |  number of input variables allowed to generate scatter plots in your
#                          : |  script via the command line:
#                          : |  "(TMVA::gConfig().GetVariablePlotting()).fMaxNumOfAllowedVariablesForScatterPlots = <some int>;"
#                          :
#                          : Some more output
#                          :
#                          : Evaluation results ranked by best signal efficiency and purity (area)
#                          : -------------------------------------------------------------------------------------------------------------------
#                          : DataSet       MVA
#                          : Name:         Method:          ROC-integ
#                          : BDT_1         BDTG           : 0.789
#                          : -------------------------------------------------------------------------------------------------------------------
#                          :
#                          : Testing efficiency compared to training efficiency (overtraining check)
#                          : -------------------------------------------------------------------------------------------------------------------
#                          : DataSet              MVA              Signal efficiency: from test sample (from training sample)
#                          : Name:                Method:          @B=0.01             @B=0.10            @B=0.30
#                          : -------------------------------------------------------------------------------------------------------------------
#                          : BDT_1                BDTG           : 0.150 (0.174)       0.476 (0.508)      0.735 (0.753)
#                          : -------------------------------------------------------------------------------------------------------------------
#                          :
# Dataset:BDT_1            : Created tree 'TestTree' with 43780 events
#                          :
# Dataset:BDT_1            : Created tree 'TrainTree' with 43780 events
#                          :
# Factory                  : Thank you for using TMVA!
#                          : For citation information, please visit: http://tmva.sf.net/citeTMVA.html
# 0%, time left: unknown
# 6%, time left: 32 sec
# 12%, time left: 29 sec
# 19%, time left: 26 sec
# 25%, time left: 24 sec
# 31%, time left: 22 sec
# 37%, time left: 20 sec
# 44%, time left: 18 sec
# 50%, time left: 16 sec
# 56%, time left: 14 sec
# 62%, time left: 12 sec
# 69%, time left: 10 sec
# 75%, time left: 8 sec
# 81%, time left: 6 sec
# 87%, time left: 4 sec
# 94%, time left: 2 sec
# 0%, time left: unknown
# 6%, time left: 2 sec
# 12%, time left: 2 sec
# 18%, time left: 2 sec
# 25%, time left: 2 sec
# 31%, time left: 2 sec
# 37%, time left: 1 sec
# 43%, time left: 1 sec
# 50%, time left: 1 sec
# 56%, time left: 1 sec
# 62%, time left: 1 sec
# 68%, time left: 0 sec
# 75%, time left: 0 sec
# 81%, time left: 0 sec
# 87%, time left: 0 sec
# 93%, time left: 0 sec
# 0%, time left: unknown
# 6%, time left: 1 sec
# 12%, time left: 1 sec
# 18%, time left: 1 sec
# 25%, time left: 1 sec
# 31%, time left: 1 sec
# 37%, time left: 1 sec
# 43%, time left: 0 sec
# 50%, time left: 0 sec
# 56%, time left: 0 sec
# 62%, time left: 0 sec
# 68%, time left: 0 sec
# 75%, time left: 0 sec
# 81%, time left: 0 sec
# 87%, time left: 0 sec
# 93%, time left: 0 sec
